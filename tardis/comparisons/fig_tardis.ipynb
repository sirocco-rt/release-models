# %% [markdown]
# # Create the tardis comparison figure for the paper

# %%
import os
os.getcwd()
# Out:
# '/Users/long/Projects/Python/release-models/tardis/comparisons'

# %%
from astropy.io import ascii
import numpy as np
import matplotlib.pyplot as plt

# %%
def make_figure(python='1d_sn.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt'):
    xpython=ascii.read(python)
    xpython.info()

    xpython['nuLnu']=xpython['Freq.']*xpython['A45P0.50']*4*np.pi*(100*3.18e18)**2


    
    xtardis=ascii.read(tardis)
    xtardis.info()
    xtardis['Lambda']=2.997e18/xtardis['nu']
    plt.plot(xpython['Lambda'],0.6e12*xpython['nuLnu'],label='Pyrite')
    plt.plot(xtardis['Lambda'],xtardis['nu']*xtardis['nuLnu'],label='Tardis')
    plt.xlim(2900,9000)
    #plt.ylim(1e52,1e55)
    plt.legend()




    
# make_figure()

# %%
make_figure(python='big.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt')

# %%
make_figure(python='test.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt')

# %%
make_figure(python='big.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt')

# %%
make_figure(python='classic.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt')

# %% [markdown]
# Classic mode is not better

# %%
make_figure(python='cv.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt')

# %%
make_figure(python='reflect.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt')

# %%
make_figure(python='standard.spec',tardis='/Users/long/Projects/tardis/tardis_snr.txt')

# %%
make_figure(python='../python/mandy.spec',tardis='../tardis/tardis_snr.txt')
# Out:
# <Table length=9998>
#    name    dtype
# --------- -------
#     Freq. float64
#    Lambda float64
#   Created float64
#  WCreated float64
#   Emitted float64
#    CenSrc float64
#      Disk   int64
#      Wind float64
#   HitSurf float64
# Scattered float64
#  A45P0.50 float64
# <Table length=1000>
#  name  dtype
# ----- -------
#    nu float64
# nuLnu float64
