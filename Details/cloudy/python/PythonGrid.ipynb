# %% [markdown]
# # Run a grid of models for comparison to cloudy
#
# This version runs things to convergence
#
# This version does not contain the summary tables

# %%
import os
os.getcwd()
# Out:
# '/Users/long/Projects/Python/release-models/cloudy/python'

# %%
import subprocess
import numpy as np
import shutil
from glob import glob

# %%
base='''System_type(star,cv,bh,agn,previous)                   bh

### Parameters for the Central Object
Central_object.mass(msol)                  0.8
Central_object.radius(cm)                  1e10
Binary.mass_sec(msol)                           0.4
Binary.period(hr)                             1000

### Parameters for the Disk (if there is one)
Disk.type(none,flat,vertically.extended,rmin>central.obj.rad)                 none

### Parameters for Boundary Layer or the compact object in an X-ray Binary or AGN
Central_object.radiation(yes,no)                  yes
Central_object.rad_type_to_make_wind(bb,models,power,cloudy,brems,mono)               cloudy
Central_object.luminosity(ergs/s)          %.3e
Central_object.power_law_index             -0.9
Central_object.geometry_for_source(sphere,lamp_post,bubble)               sphere
Central_object.cloudy.low_energy_break(ev)                .136
Central_object.cloudy.high_energy_break(ev)               20000

### Parameters describing the various winds or coronae in the system
Wind.number_of_components                  1
Wind.type(SV,star,hydro,corona,kwd,homologous,shell,imported)                shell

### Parameters associated with photon number, cycles,ionization and radiative transfer options
Photons_per_cycle                          10000000
Ionization_cycles                          30
Spectrum_cycles                            0
Wind.ionization(on.the.spot,ML93,LTE_tr,LTE_te,fixed,matrix_bb,matrix_pow,matrix_est)           matrix_pow
Line_transfer(pure_abs,pure_scat,sing_scat,escape_prob,thermal_trapping,macro_atoms_escape_prob,macro_atoms_thermal_trapping)     thermal_trapping
Wind.radiation(yes,no)                           no
Atomic_data                                data/standard80.dat
Surface.reflection.or.absorption(reflect,absorb,thermalized.rerad)              reflect
Wind_heating.extra_processes(none,adiabatic,nonthermal,both)                 none

### Parameters for Domain 0
Shell.wind_mdot(msol/yr)                   4.7e-20
Shell.wind.radmin(cm)                      1e11
Shell.wind.radmax(cm)                      1.00000000001e11
Shell.wind_v_at_rmin(cm)                   1
Shell.wind.v_at_rmax(cm)                   1.000010
Shell.wind.acceleration_exponent           1
Wind.t.init                                10000
Wind.filling_factor(1=smooth,<1=clumped)   1

### Parameters for Reverberation Modeling (if needed)
Reverb.type(none,photon,wind,matom)                 none

### Other parameters
Photon_sampling.approach(T_star,cv,yso,AGN,tde_bb,min_max_freq,user_bands,cloudy_test,wide,logarithmic)          cloudy_test
Photon_sampling.low_energy_limit(eV)            0.13
Photon_sampling.high_energy_limit(eV)                 1e8
'''

# %%
def run_one(log_ip=-8,version='87h'):

    if log_ip<0:
        pfname='xx_m%03.2f' % (-log_ip)
    else:
        pfname='xx_p%03.2f' % (log_ip)
    

    f=open(pfname+'.pf','w')
    
    xlum=1e21 * 10**(log_ip+8.0)

    print(xlum)
    
    f.write(base % xlum)
    f.close()

    py='py%s' % version
  

    xcommand='mpirun -np 8 %s -p %s > %s.out.txt' % (py,pfname,pfname)
    print(xcommand)
    subprocess.run(xcommand,shell=True, check=True)

    try:
        signame= '%s.sig' % pfname
        f=open(signame)
    except:
        print('Error: Could not open %s ' % signame)
        return 1
        

    lines=f.readlines()
    last_line=lines[-1]
    print(last_line)
    if last_line.count('COMPLETE'):
        windsave2table = 'windsave2table%s' % version
        xcommand='%s %s >> %s.out.txt' % (windsave2table,pfname,pfname)
        # print(xcommand)
        subprocess.run(xcommand,shell=True, check=True)
        return 0
    return 1
              
run_one()
# Out:
# 1e+21
# mpirun -np 8 py87h -p xx_m8.00 > xx_m8.00.out.txt
# Fri Mar  8 17:39:31 2024    100.4 COMPLETE             xx_m8.00
# 0

# %%
def do_many(log_ipmin=-5,log_ipmax=8,npts=10,version='87h'):
    log_ip=np.linspace(log_ipmin,log_ipmax,npts)
    # print(log_ip)
    i=1
    for one in log_ip:
        if one<0:
            pfname='xx_m%03.2f' % (-one)
        else:
            pfname='xx_p%03.2f' % (one)
        ival=run_one(one,version)
        if ival==0:
            os.remove(pfname+'.wind_save')
            shutil.rmtree('diag_%s' % pfname)
            files = glob('%s*spec*' % pfname)
            # print(files)
            for one_file in files:
                os.remove(one_file)
            print('Finished %s successfully (%d/%d)' % (pfname,i,len(log_ip)))
        else:
            print('Failed on %s  (%d/%d)' % (pfname,i,len(log_ip)))
        i+=1
                  
        
            
            
            

do_many(npts=100,version='87h')
# Out:
# 1e+24
# mpirun -np 8 py87h -p xx_m5.00 > xx_m5.00.out.txt
# Fri Mar  8 17:41:23 2024    110.6 COMPLETE             xx_m5.00
#
# Finished xx_m5.00 successfully (1/100)
# 1.3530477745798076e+24
# mpirun -np 8 py87h -p xx_m4.87 > xx_m4.87.out.txt
# Fri Mar  8 17:43:14 2024    110.1 COMPLETE             xx_m4.87
#
# Finished xx_m4.87 successfully (2/100)
# 1.8307382802953697e+24
# mpirun -np 8 py87h -p xx_m4.74 > xx_m4.74.out.txt
# Fri Mar  8 17:45:04 2024    109.2 COMPLETE             xx_m4.74
#
# Finished xx_m4.74 successfully (3/100)
# 2.477076355991709e+24
# mpirun -np 8 py87h -p xx_m4.61 > xx_m4.61.out.txt
# Fri Mar  8 17:46:54 2024    109.2 COMPLETE             xx_m4.61
#
# Finished xx_m4.61 successfully (4/100)
# 3.3516026509388406e+24
# mpirun -np 8 py87h -p xx_m4.47 > xx_m4.47.out.txt
# Fri Mar  8 17:48:41 2024    106.1 COMPLETE             xx_m4.47
#
# Finished xx_m4.47 successfully (5/100)
# 4.5348785081285823e+24
# mpirun -np 8 py87h -p xx_m4.34 > xx_m4.34.out.txt
# Fri Mar  8 17:50:23 2024    101.7 COMPLETE             xx_m4.34
#
# Finished xx_m4.34 successfully (6/100)
# 6.135907273413176e+24
# mpirun -np 8 py87h -p xx_m4.21 > xx_m4.21.out.txt
# Fri Mar  8 17:52:04 2024    100.0 COMPLETE             xx_m4.21
#
# Finished xx_m4.21 successfully (7/100)
# 8.302175681319752e+24
# mpirun -np 8 py87h -p xx_m4.08 > xx_m4.08.out.txt
# Fri Mar  8 17:53:46 2024    100.7 COMPLETE             xx_m4.08
#
# Finished xx_m4.08 successfully (8/100)
# 1.1233240329780266e+25
# mpirun -np 8 py87h -p xx_m3.95 > xx_m3.95.out.txt
# Fri Mar  8 17:55:28 2024    101.2 COMPLETE             xx_m3.95
#
# Finished xx_m3.95 successfully (9/100)
# 1.5199110829529331e+25
# mpirun -np 8 py87h -p xx_m3.82 > xx_m3.82.out.txt
# Fri Mar  8 17:57:11 2024    102.1 COMPLETE             xx_m3.82
#
# Finished xx_m3.82 successfully (10/100)
# 2.0565123083486518e+25
# mpirun -np 8 py87h -p xx_m3.69 > xx_m3.69.out.txt
# Fri Mar  8 17:58:54 2024    102.2 COMPLETE             xx_m3.69
#
# Finished xx_m3.69 successfully (11/100)
# 2.782559402207126e+25
# mpirun -np 8 py87h -p xx_m3.56 > xx_m3.56.out.txt
# Fri Mar  8 18:00:37 2024    102.9 COMPLETE             xx_m3.56
#
# Finished xx_m3.56 successfully (12/100)
# 3.764935806792471e+25
# mpirun -np 8 py87h -p xx_m3.42 > xx_m3.42.out.txt
# Fri Mar  8 18:02:21 2024    102.8 COMPLETE             xx_m3.42
#
# Finished xx_m3.42 successfully (13/100)
# 5.094138014816386e+25
# mpirun -np 8 py87h -p xx_m3.29 > xx_m3.29.out.txt
# Fri Mar  8 18:04:06 2024    103.7 COMPLETE             xx_m3.29
#
# Finished xx_m3.29 successfully (14/100)
# 6.892612104349708e+25
# mpirun -np 8 py87h -p xx_m3.16 > xx_m3.16.out.txt
# Fri Mar  8 18:05:51 2024    104.2 COMPLETE             xx_m3.16
#
# Finished xx_m3.16 successfully (15/100)
# 9.3260334688322e+25
# mpirun -np 8 py87h -p xx_m3.03 > xx_m3.03.out.txt
# Fri Mar  8 18:07:36 2024    104.7 COMPLETE             xx_m3.03
#
# Finished xx_m3.03 successfully (16/100)
# 1.261856883066021e+26
# mpirun -np 8 py87h -p xx_m2.90 > xx_m2.90.out.txt
# Fri Mar  8 18:09:22 2024    105.0 COMPLETE             xx_m2.90
#
# Finished xx_m2.90 successfully (17/100)
# 1.707352647470692e+26
# mpirun -np 8 py87h -p xx_m2.77 > xx_m2.77.out.txt
# Fri Mar  8 18:11:08 2024    105.5 COMPLETE             xx_m2.77
#
# Finished xx_m2.77 successfully (18/100)
# 2.310129700083158e+26
# mpirun -np 8 py87h -p xx_m2.64 > xx_m2.64.out.txt
# Fri Mar  8 18:12:56 2024    106.8 COMPLETE             xx_m2.64
#
# Finished xx_m2.64 successfully (19/100)
# 3.1257158496882357e+26
# mpirun -np 8 py87h -p xx_m2.51 > xx_m2.51.out.txt
# Fri Mar  8 18:14:44 2024    106.8 COMPLETE             xx_m2.51
#
# Finished xx_m2.51 successfully (20/100)
# 4.229242874389499e+26
# mpirun -np 8 py87h -p xx_m2.37 > xx_m2.37.out.txt
# Fri Mar  8 18:16:33 2024    108.3 COMPLETE             xx_m2.37
#
# Finished xx_m2.37 successfully (21/100)
# 5.7223676593502204e+26
# mpirun -np 8 py87h -p xx_m2.24 > xx_m2.24.out.txt
# Fri Mar  8 18:18:23 2024    109.5 COMPLETE             xx_m2.24
#
# Finished xx_m2.24 successfully (22/100)
# 7.742636826811278e+26
# mpirun -np 8 py87h -p xx_m2.11 > xx_m2.11.out.txt
# Fri Mar  8 18:20:14 2024    110.0 COMPLETE             xx_m2.11
#
# Finished xx_m2.11 successfully (23/100)
# 1.0476157527896661e+27
# mpirun -np 8 py87h -p xx_m1.98 > xx_m1.98.out.txt
# Fri Mar  8 18:22:05 2024    110.5 COMPLETE             xx_m1.98
#
# Finished xx_m1.98 successfully (24/100)
# 1.4174741629268076e+27
# mpirun -np 8 py87h -p xx_m1.85 > xx_m1.85.out.txt
# Fri Mar  8 18:23:57 2024    111.4 COMPLETE             xx_m1.85
#
# Finished xx_m1.85 successfully (25/100)
# 1.9179102616724927e+27
# mpirun -np 8 py87h -p xx_m1.72 > xx_m1.72.out.txt
# Fri Mar  8 18:25:51 2024    113.1 COMPLETE             xx_m1.72
#
# Finished xx_m1.72 successfully (26/100)
# 2.5950242113997375e+27
# mpirun -np 8 py87h -p xx_m1.59 > xx_m1.59.out.txt
# Fri Mar  8 18:27:46 2024    113.4 COMPLETE             xx_m1.59
#
# Finished xx_m1.59 successfully (27/100)
# 3.5111917342151345e+27
# mpirun -np 8 py87h -p xx_m1.45 > xx_m1.45.out.txt
# Fri Mar  8 18:29:42 2024    115.1 COMPLETE             xx_m1.45
#
# Finished xx_m1.45 successfully (28/100)
# 4.750810162102803e+27
# mpirun -np 8 py87h -p xx_m1.32 > xx_m1.32.out.txt
# Fri Mar  8 18:31:38 2024    115.8 COMPLETE             xx_m1.32
#
# Finished xx_m1.32 successfully (29/100)
# 6.428073117284319e+27
# mpirun -np 8 py87h -p xx_m1.19 > xx_m1.19.out.txt
# Fri Mar  8 18:33:36 2024    116.8 COMPLETE             xx_m1.19
#
# Finished xx_m1.19 successfully (30/100)
# 8.697490026177835e+27
# mpirun -np 8 py87h -p xx_m1.06 > xx_m1.06.out.txt
# Fri Mar  8 18:35:34 2024    117.4 COMPLETE             xx_m1.06
#
# Finished xx_m1.06 successfully (31/100)
# 1.1768119524349992e+28
# mpirun -np 8 py87h -p xx_m0.93 > xx_m0.93.out.txt
# Fri Mar  8 18:37:32 2024    117.2 COMPLETE             xx_m0.93
#
# Finished xx_m0.93 successfully (32/100)
# 1.592282793341094e+28
# mpirun -np 8 py87h -p xx_m0.80 > xx_m0.80.out.txt
# Fri Mar  8 18:39:29 2024    116.4 COMPLETE             xx_m0.80
#
# Finished xx_m0.80 successfully (33/100)
# 2.1544346900318864e+28
# mpirun -np 8 py87h -p xx_m0.67 > xx_m0.67.out.txt
# Fri Mar  8 18:41:26 2024    115.9 COMPLETE             xx_m0.67
#
# Finished xx_m0.67 successfully (34/100)
# 2.9150530628251816e+28
# mpirun -np 8 py87h -p xx_m0.54 > xx_m0.54.out.txt
# Fri Mar  8 18:43:23 2024    116.5 COMPLETE             xx_m0.54
#
# Finished xx_m0.54 successfully (35/100)
# 3.9442060594376558e+28
# mpirun -np 8 py87h -p xx_m0.40 > xx_m0.40.out.txt
# Fri Mar  8 18:45:21 2024    116.6 COMPLETE             xx_m0.40
#
# Finished xx_m0.40 successfully (36/100)
# 5.336699231206313e+28
# mpirun -np 8 py87h -p xx_m0.27 > xx_m0.27.out.txt
# Fri Mar  8 18:47:17 2024    115.4 COMPLETE             xx_m0.27
#
# Finished xx_m0.27 successfully (37/100)
# 7.220809018385471e+28
# mpirun -np 8 py87h -p xx_m0.14 > xx_m0.14.out.txt
# Fri Mar  8 18:49:13 2024    115.8 COMPLETE             xx_m0.14
#
# Finished xx_m0.14 successfully (38/100)
# 9.770099572992266e+28
# mpirun -np 8 py87h -p xx_m0.01 > xx_m0.01.out.txt
# Fri Mar  8 18:51:09 2024    115.2 COMPLETE             xx_m0.01
#
# Finished xx_m0.01 successfully (39/100)
# 1.3219411484660288e+29
# mpirun -np 8 py87h -p xx_p0.12 > xx_p0.12.out.txt
# Fri Mar  8 18:53:05 2024    115.2 COMPLETE             xx_p0.12
#
# Finished xx_p0.12 successfully (40/100)
# 1.788649529057435e+29
# mpirun -np 8 py87h -p xx_p0.25 > xx_p0.25.out.txt
# Fri Mar  8 18:55:01 2024    115.0 COMPLETE             xx_p0.25
#
# Finished xx_p0.25 successfully (41/100)
# 2.4201282647943833e+29
# mpirun -np 8 py87h -p xx_p0.38 > xx_p0.38.out.txt
# Fri Mar  8 18:56:56 2024    114.1 COMPLETE             xx_p0.38
#
# Finished xx_p0.38 successfully (42/100)
# 3.274549162877732e+29
# mpirun -np 8 py87h -p xx_p0.52 > xx_p0.52.out.txt
# Fri Mar  8 18:58:50 2024    113.1 COMPLETE             xx_p0.52
#
# Finished xx_p0.52 successfully (43/100)
# 4.4306214575838866e+29
# mpirun -np 8 py87h -p xx_p0.65 > xx_p0.65.out.txt
# Fri Mar  8 19:00:44 2024    112.8 COMPLETE             xx_p0.65
#
# Finished xx_p0.65 successfully (44/100)
# 5.9948425031894205e+29
# mpirun -np 8 py87h -p xx_p0.78 > xx_p0.78.out.txt
# Fri Mar  8 19:02:37 2024    112.6 COMPLETE             xx_p0.78
#
# Finished xx_p0.78 successfully (45/100)
# 8.11130830789689e+29
# mpirun -np 8 py87h -p xx_p0.91 > xx_p0.91.out.txt
# Fri Mar  8 19:04:31 2024    112.5 COMPLETE             xx_p0.91
#
# Finished xx_p0.91 successfully (46/100)
# 1.0974987654930589e+30
# mpirun -np 8 py87h -p xx_p1.04 > xx_p1.04.out.txt
# Fri Mar  8 19:06:22 2024    110.5 COMPLETE             xx_p1.04
#
# Finished xx_p1.04 successfully (47/100)
# 1.4849682622544697e+30
# mpirun -np 8 py87h -p xx_p1.17 > xx_p1.17.out.txt
# Fri Mar  8 19:08:06 2024    102.8 COMPLETE             xx_p1.17
#
# Finished xx_p1.17 successfully (48/100)
# 2.0092330025650542e+30
# mpirun -np 8 py87h -p xx_p1.30 > xx_p1.30.out.txt
# Fri Mar  8 19:09:44 2024     97.2 COMPLETE             xx_p1.30
#
# Finished xx_p1.30 successfully (49/100)
# 2.718588242732951e+30
# mpirun -np 8 py87h -p xx_p1.43 > xx_p1.43.out.txt
# Fri Mar  8 19:11:20 2024     95.6 COMPLETE             xx_p1.43
#
# Finished xx_p1.43 successfully (50/100)
# 3.6783797718286493e+30
# mpirun -np 8 py87h -p xx_p1.57 > xx_p1.57.out.txt
# Fri Mar  8 19:12:58 2024     96.6 COMPLETE             xx_p1.57
#
# Finished xx_p1.57 successfully (51/100)
# 4.9770235643321145e+30
# mpirun -np 8 py87h -p xx_p1.70 > xx_p1.70.out.txt
# Fri Mar  8 19:14:31 2024     92.8 COMPLETE             xx_p1.70
#
# Finished xx_p1.70 successfully (52/100)
# 6.734150657750829e+30
# mpirun -np 8 py87h -p xx_p1.83 > xx_p1.83.out.txt
# Fri Mar  8 19:16:01 2024     89.1 COMPLETE             xx_p1.83
#
# Finished xx_p1.83 successfully (53/100)
# 9.111627561154905e+30
# mpirun -np 8 py87h -p xx_p1.96 > xx_p1.96.out.txt
# Fri Mar  8 19:17:29 2024     87.0 COMPLETE             xx_p1.96
#
# Finished xx_p1.96 successfully (54/100)
# 1.2328467394420684e+31
# mpirun -np 8 py87h -p xx_p2.09 > xx_p2.09.out.txt
# Fri Mar  8 19:18:52 2024     82.3 COMPLETE             xx_p2.09
#
# Finished xx_p2.09 successfully (55/100)
# 1.6681005372000626e+31
# mpirun -np 8 py87h -p xx_p2.22 > xx_p2.22.out.txt
# Fri Mar  8 19:20:10 2024     77.5 COMPLETE             xx_p2.22
#
# Finished xx_p2.22 successfully (56/100)
# 2.257019719633926e+31
# mpirun -np 8 py87h -p xx_p2.35 > xx_p2.35.out.txt
# Fri Mar  8 19:21:25 2024     73.4 COMPLETE             xx_p2.35
#
# Finished xx_p2.35 successfully (57/100)
# 3.0538555088334123e+31
# mpirun -np 8 py87h -p xx_p2.48 > xx_p2.48.out.txt
# Fri Mar  8 19:22:37 2024     71.6 COMPLETE             xx_p2.48
#
# Finished xx_p2.48 successfully (58/100)
# 4.132012400115334e+31
# mpirun -np 8 py87h -p xx_p2.62 > xx_p2.62.out.txt
# Fri Mar  8 19:23:47 2024     69.2 COMPLETE             xx_p2.62
#
# Finished xx_p2.62 successfully (59/100)
# 5.590810182512222e+31
# mpirun -np 8 py87h -p xx_p2.75 > xx_p2.75.out.txt
# Fri Mar  8 19:24:55 2024     66.9 COMPLETE             xx_p2.75
#
# Finished xx_p2.75 successfully (60/100)
# 7.564633275546291e+31
# mpirun -np 8 py87h -p xx_p2.88 > xx_p2.88.out.txt
# Fri Mar  8 19:26:00 2024     64.9 COMPLETE             xx_p2.88
#
# Finished xx_p2.88 successfully (61/100)
# 1.0235310218990267e+32
# mpirun -np 8 py87h -p xx_p3.01 > xx_p3.01.out.txt
# Fri Mar  8 19:27:05 2024     63.2 COMPLETE             xx_p3.01
#
# Finished xx_p3.01 successfully (62/100)
# 1.3848863713938745e+32
# mpirun -np 8 py87h -p xx_p3.14 > xx_p3.14.out.txt
# Fri Mar  8 19:28:07 2024     61.6 COMPLETE             xx_p3.14
#
# Finished xx_p3.14 successfully (63/100)
# 1.873817422860387e+32
# mpirun -np 8 py87h -p xx_p3.27 > xx_p3.27.out.txt
# Fri Mar  8 19:29:08 2024     60.2 COMPLETE             xx_p3.27
#
# Finished xx_p3.27 successfully (64/100)
# 2.5353644939701167e+32
# mpirun -np 8 py87h -p xx_p3.40 > xx_p3.40.out.txt
# Fri Mar  8 19:30:08 2024     59.2 COMPLETE             xx_p3.40
#
# Finished xx_p3.40 successfully (65/100)
# 3.430469286314926e+32
# mpirun -np 8 py87h -p xx_p3.54 > xx_p3.54.out.txt
# Fri Mar  8 19:31:07 2024     58.4 COMPLETE             xx_p3.54
#
# Finished xx_p3.54 successfully (66/100)
# 4.641588833612792e+32
# mpirun -np 8 py87h -p xx_p3.67 > xx_p3.67.out.txt
# Fri Mar  8 19:32:05 2024     57.3 COMPLETE             xx_p3.67
#
# Finished xx_p3.67 successfully (67/100)
# 6.280291441834272e+32
# mpirun -np 8 py87h -p xx_p3.80 > xx_p3.80.out.txt
# Fri Mar  8 19:33:03 2024     56.8 COMPLETE             xx_p3.80
#
# Finished xx_p3.80 successfully (68/100)
# 8.497534359086474e+32
# mpirun -np 8 py87h -p xx_p3.93 > xx_p3.93.out.txt
# Fri Mar  8 19:33:59 2024     55.6 COMPLETE             xx_p3.93
#
# Finished xx_p3.93 successfully (69/100)
# 1.1497569953977402e+33
# mpirun -np 8 py87h -p xx_p4.06 > xx_p4.06.out.txt
# Fri Mar  8 19:34:55 2024     55.2 COMPLETE             xx_p4.06
#
# Finished xx_p4.06 successfully (70/100)
# 1.5556761439304723e+33
# mpirun -np 8 py87h -p xx_p4.19 > xx_p4.19.out.txt
# Fri Mar  8 19:35:50 2024     54.2 COMPLETE             xx_p4.19
#
# Finished xx_p4.19 successfully (71/100)
# 2.1049041445120218e+33
# mpirun -np 8 py87h -p xx_p4.32 > xx_p4.32.out.txt
# Fri Mar  8 19:36:45 2024     53.6 COMPLETE             xx_p4.32
#
# Finished xx_p4.32 successfully (72/100)
# 2.848035868435805e+33
# mpirun -np 8 py87h -p xx_p4.45 > xx_p4.45.out.txt
# Fri Mar  8 19:37:39 2024     53.0 COMPLETE             xx_p4.45
#
# Finished xx_p4.45 successfully (73/100)
# 3.8535285937105353e+33
# mpirun -np 8 py87h -p xx_p4.59 > xx_p4.59.out.txt
# Fri Mar  8 19:38:32 2024     52.5 COMPLETE             xx_p4.59
#
# Finished xx_p4.59 successfully (74/100)
# 5.214008287999695e+33
# mpirun -np 8 py87h -p xx_p4.72 > xx_p4.72.out.txt
# Fri Mar  8 19:39:25 2024     51.9 COMPLETE             xx_p4.72
#
# Finished xx_p4.72 successfully (75/100)
# 7.05480231071866e+33
# mpirun -np 8 py87h -p xx_p4.85 > xx_p4.85.out.txt
# Fri Mar  8 19:40:17 2024     51.5 COMPLETE             xx_p4.85
#
# Finished xx_p4.85 successfully (76/100)
# 9.545484566618367e+33
# mpirun -np 8 py87h -p xx_p4.98 > xx_p4.98.out.txt
# Fri Mar  8 19:41:09 2024     51.0 COMPLETE             xx_p4.98
#
# Finished xx_p4.98 successfully (77/100)
# 1.291549665014888e+34
# mpirun -np 8 py87h -p xx_p5.11 > xx_p5.11.out.txt
# Fri Mar  8 19:42:00 2024     50.7 COMPLETE             xx_p5.11
#
# Finished xx_p5.11 successfully (78/100)
# 1.7475284000076901e+34
# mpirun -np 8 py87h -p xx_p5.24 > xx_p5.24.out.txt
# Fri Mar  8 19:42:52 2024     50.4 COMPLETE             xx_p5.24
#
# Finished xx_p5.24 successfully (79/100)
# 2.364489412645417e+34
# mpirun -np 8 py87h -p xx_p5.37 > xx_p5.37.out.txt
# Fri Mar  8 19:43:43 2024     50.3 COMPLETE             xx_p5.37
#
# Finished xx_p5.37 successfully (80/100)
# 3.1992671377973845e+34
# mpirun -np 8 py87h -p xx_p5.51 > xx_p5.51.out.txt
# Fri Mar  8 19:44:33 2024     50.0 COMPLETE             xx_p5.51
#
# Finished xx_p5.51 successfully (81/100)
# 4.328761281083062e+34
# mpirun -np 8 py87h -p xx_p5.64 > xx_p5.64.out.txt
# Fri Mar  8 19:45:24 2024     49.7 COMPLETE             xx_p5.64
#
# Finished xx_p5.64 successfully (82/100)
# 5.857020818056674e+34
# mpirun -np 8 py87h -p xx_p5.77 > xx_p5.77.out.txt
# Fri Mar  8 19:46:14 2024     49.7 COMPLETE             xx_p5.77
#
# Finished xx_p5.77 successfully (83/100)
# 7.924828983539186e+34
# mpirun -np 8 py87h -p xx_p5.90 > xx_p5.90.out.txt
# Fri Mar  8 19:47:05 2024     49.4 COMPLETE             xx_p5.90
#
# Finished xx_p5.90 successfully (84/100)
# 1.0722672220103253e+35
# mpirun -np 8 py87h -p xx_p6.03 > xx_p6.03.out.txt
# Fri Mar  8 19:47:55 2024     49.1 COMPLETE             xx_p6.03
#
# Finished xx_p6.03 successfully (85/100)
# 1.4508287784959431e+35
# mpirun -np 8 py87h -p xx_p6.16 > xx_p6.16.out.txt
# Fri Mar  8 19:48:44 2024     49.1 COMPLETE             xx_p6.16
#
# Finished xx_p6.16 successfully (86/100)
# 1.9630406500402767e+35
# mpirun -np 8 py87h -p xx_p6.29 > xx_p6.29.out.txt
# Fri Mar  8 19:49:34 2024     49.1 COMPLETE             xx_p6.29
#
# Finished xx_p6.29 successfully (87/100)
# 2.6560877829466946e+35
# mpirun -np 8 py87h -p xx_p6.42 > xx_p6.42.out.txt
# Fri Mar  8 19:50:24 2024     48.8 COMPLETE             xx_p6.42
#
# Finished xx_p6.42 successfully (88/100)
# 3.5938136638046406e+35
# mpirun -np 8 py87h -p xx_p6.56 > xx_p6.56.out.txt
# Fri Mar  8 19:51:13 2024     48.6 COMPLETE             xx_p6.56
#
# Finished xx_p6.56 successfully (89/100)
# 4.862601580065373e+35
# mpirun -np 8 py87h -p xx_p6.69 > xx_p6.69.out.txt
# Fri Mar  8 19:52:03 2024     48.6 COMPLETE             xx_p6.69
#
# Finished xx_p6.69 successfully (90/100)
# 6.5793322465757084e+35
# mpirun -np 8 py87h -p xx_p6.82 > xx_p6.82.out.txt
# Fri Mar  8 19:52:52 2024     48.3 COMPLETE             xx_p6.82
#
# Finished xx_p6.82 successfully (91/100)
# 8.902150854450392e+35
# mpirun -np 8 py87h -p xx_p6.95 > xx_p6.95.out.txt
# Fri Mar  8 19:53:41 2024     48.3 COMPLETE             xx_p6.95
#
# Finished xx_p6.95 successfully (92/100)
# 1.2045035402587836e+36
# mpirun -np 8 py87h -p xx_p7.08 > xx_p7.08.out.txt
# Fri Mar  8 19:54:30 2024     48.0 COMPLETE             xx_p7.08
#
# Finished xx_p7.08 successfully (93/100)
# 1.6297508346206468e+36
# mpirun -np 8 py87h -p xx_p7.21 > xx_p7.21.out.txt
# Fri Mar  8 19:55:18 2024     47.8 COMPLETE             xx_p7.21
#
# Finished xx_p7.21 successfully (94/100)
# 2.2051307399030504e+36
# mpirun -np 8 py87h -p xx_p7.34 > xx_p7.34.out.txt
# Fri Mar  8 19:56:07 2024     47.7 COMPLETE             xx_p7.34
#
# Finished xx_p7.34 successfully (95/100)
# 2.9836472402833464e+36
# mpirun -np 8 py87h -p xx_p7.47 > xx_p7.47.out.txt
# Fri Mar  8 19:56:55 2024     47.6 COMPLETE             xx_p7.47
#
# Finished xx_p7.47 successfully (96/100)
# 4.037017258596566e+36
# mpirun -np 8 py87h -p xx_p7.61 > xx_p7.61.out.txt
# Fri Mar  8 19:57:44 2024     47.5 COMPLETE             xx_p7.61
#
# Finished xx_p7.61 successfully (97/100)
# 5.462277217684359e+36
# mpirun -np 8 py87h -p xx_p7.74 > xx_p7.74.out.txt
# Fri Mar  8 19:58:32 2024     47.7 COMPLETE             xx_p7.74
#
# Finished xx_p7.74 successfully (98/100)
# 7.390722033525806e+36
# mpirun -np 8 py87h -p xx_p7.87 > xx_p7.87.out.txt
# Fri Mar  8 19:59:20 2024     47.3 COMPLETE             xx_p7.87
#
# Finished xx_p7.87 successfully (99/100)
# 1e+37
# mpirun -np 8 py87h -p xx_p8.00 > xx_p8.00.out.txt
# Fri Mar  8 20:00:09 2024     47.5 COMPLETE             xx_p8.00
#
# Finished xx_p8.00 successfully (100/100)
